# %% [markdown]
# <a href="https://colab.research.google.com/github/danifemarsil30-blip/1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio Numero 4
edadjuan=9
edadalberto=(2/3)*edadjuan
edana=(4/3)*edadjuan
edadmama=edadjuan+edadalberto+edana

print("edadjuan",edadjuan)
print("edadalberto",edadalberto)
print("edadana",edana)
print("edadmama",edadmama)
# Out:
# edadjuan 9
# edadalberto 6.0
# edadana 12.0
# edadmama 27.0

# %%
#Ejercicio Numero 5
suma = 0
X = 20
suma = suma + X
Y = 40
X = X + (Y ** 2)
suma = suma + (X // Y)
print("EL VALOR DE LA SUMA ES:", suma)
# Out:
# EL VALOR DE LA SUMA ES: 60

# %%
#Ejercicio Numero 12
horas=48
salariosemanal=(5000*horas)
retencion=(salariosemanal*0.125)
salarioneto=(salariosemanal-retencion)
print("salarioneto",salarioneto)
print("retencio en la fuente",retencion)
print("salario bruto",salariosemanal)
# Out:
# salarioneto 210000.0
# retencio en la fuente 30000.0
# salario bruto 240000

# %%
#Ejercicio numero 14
numero=78
cuadrado=(numero*numero)
cubo=(cuadrado*numero)
print("numero",numero)
print("cuadrado",cuadrado)
print("cubo",cubo)
# Out:
# numero 78
# cuadrado 6084
# cubo 474552

# %%
#Ejercicio Numero 17
radio=(20)
π=(3.14)
areacirculo=(π*radio**2)
loncircunferencia=(2*π*radio)
print("areacirculo",areacirculo)
print("loncircunferencia",loncircunferencia)
# Out:
# areacirculo 1256.0
# loncircunferencia 125.60000000000001
